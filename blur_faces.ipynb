# %%
import urllib.request

url = "https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml"
save_path = r"C:\Users\micha\Documents\haarcascade_frontalface_default.xml"  # choose any folder
urllib.request.urlretrieve(url, save_path)

print(f"Downloaded Haar cascade to: {save_path}")
# Out:
# Downloaded Haar cascade to: C:\Users\micha\Documents\haarcascade_frontalface_default.xml

# %%
import cv2
import os

# Load Haar cascade
face_cascade_path = r"C:\Users\micha\Documents\haarcascade_frontalface_default.xml"
face_cascade = cv2.CascadeClassifier(face_cascade_path)

if face_cascade.empty():
    raise Exception("Failed to load Haar cascade XML!")

# Start from current working directory
root_dir = os.getcwd()

# Recursively process all .jpg files
for dirpath, dirnames, filenames in os.walk(root_dir):
    for filename in filenames:
        if filename.lower().endswith(".jpg"):
            img_path = os.path.join(dirpath, filename)
            img = cv2.imread(img_path)
            if img is None:
                print(f"Failed to read {img_path}, skipping")
                continue

            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

            # Blur each detected face
            for (x, y, w, h) in faces:
                face = img[y:y+h, x:x+w]
                face_blurred = cv2.GaussianBlur(face, (51, 51), 30)
                img[y:y+h, x:x+w] = face_blurred

            # Overwrite the original image
            cv2.imwrite(img_path, img)
            print(f"Processed and overwritten: {img_path}")

print("All images in all subfolders processed")
# Out:
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\1.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\10.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\11.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\12.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\13.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\14.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\15.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\16.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\17.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\18.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\19.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\2.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\20.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\21.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\22.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\23.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\24.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\3.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\4.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\5.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\6.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\7.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\8.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\images\9.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\1.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\10.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\11.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\12.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\13.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\14.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\15.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\16.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\17.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\18.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\19.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\2.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\20.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\21.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\22.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\23.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\24.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\3.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\4.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\5.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\6.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\7.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\8.jpg
# Processed and overwritten: c:\Users\micha\danva2-web-report\stimFiles\adultFaces\9.jpg
# All images in all subfolders processed
